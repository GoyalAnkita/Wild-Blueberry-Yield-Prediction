# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the file

data=pd.read_csv("WildBlueberryPollinationSimulationData.csv")

# %%
data.head(5)
# Out:
#    Row#  clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0     0       37.5      0.75     0.25     0.25   0.25              86.0
# 1     1       37.5      0.75     0.25     0.25   0.25              86.0
# 2     2       37.5      0.75     0.25     0.25   0.25              94.6
# 3     3       37.5      0.75     0.25     0.25   0.25              94.6
# 4     4       37.5      0.75     0.25     0.25   0.25              86.0
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              52.0                  71.9              62.0              30.0
# 2              57.2                  79.0              68.2              33.0
# 3              57.2                  79.0              68.2              33.0
# 4              52.0                  71.9              62.0              30.0
#
# ...

# %%
data.describe()
#Gives statistics about numerical values
# Out:
#              Row#   clonesize    honeybee     bumbles     andrena       osmia  \
# count  777.000000  777.000000  777.000000  777.000000  777.000000  777.000000
# mean   388.000000   18.767696    0.417133    0.282389    0.468817    0.562062
# std    224.444871    6.999063    0.978904    0.066343    0.161052    0.169119
# min      0.000000   10.000000    0.000000    0.000000    0.000000    0.000000
# 25%    194.000000   12.500000    0.250000    0.250000    0.380000    0.500000
# 50%    388.000000   12.500000    0.250000    0.250000    0.500000    0.630000
# 75%    582.000000   25.000000    0.500000    0.380000    0.630000    0.750000
# max    776.000000   40.000000   18.430000    0.585000    0.750000    0.750000
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count        777.000000        777.000000            777.000000
# mean          82.277091         49.700515             68.723037
# std            9.193745          5.595769              7.676984
# ...

# %%
data.shape
# Out:
# (777, 18)

# %%
data.columns
# Out:
# Index(['Row#', 'clonesize', 'honeybee', 'bumbles', 'andrena', 'osmia',
#        'MaxOfUpperTRange', 'MinOfUpperTRange', 'AverageOfUpperTRange',
#        'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange',
#        'RainingDays', 'AverageRainingDays', 'fruitset', 'fruitmass', 'seeds',
#        'yield'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Row#                      int64
# clonesize               float64
# honeybee                float64
# bumbles                 float64
# andrena                 float64
# osmia                   float64
# MaxOfUpperTRange        float64
# MinOfUpperTRange        float64
# AverageOfUpperTRange    float64
# MaxOfLowerTRange        float64
# MinOfLowerTRange        float64
# AverageOfLowerTRange    float64
# RainingDays             float64
# AverageRainingDays      float64
# fruitset                float64
# fruitmass               float64
# seeds                   float64
# yield                   float64
# dtype: object

# %%
data.nunique()
#Counts number of distinct elements in specified axis
# Out:
# Row#                    777
# clonesize                 6
# honeybee                  7
# bumbles                  10
# andrena                  12
# osmia                    12
# MaxOfUpperTRange          5
# MinOfUpperTRange          5
# AverageOfUpperTRange      5
# MaxOfLowerTRange          5
# MinOfLowerTRange          5
# AverageOfLowerTRange      5
# RainingDays               5
# AverageRainingDays        5
# fruitset                777
# fruitmass               777
# seeds                   777
# yield                   777
# dtype: int64

# %%
#look for missing values

data.isnull().sum()/data.shape[0]

#We dont have any missing values in our dataset
# Out:
# Row#                    0.0
# clonesize               0.0
# honeybee                0.0
# bumbles                 0.0
# andrena                 0.0
# osmia                   0.0
# MaxOfUpperTRange        0.0
# MinOfUpperTRange        0.0
# AverageOfUpperTRange    0.0
# MaxOfLowerTRange        0.0
# MinOfLowerTRange        0.0
# AverageOfLowerTRange    0.0
# RainingDays             0.0
# AverageRainingDays      0.0
# fruitset                0.0
# fruitmass               0.0
# seeds                   0.0
# yield                   0.0
# dtype: float64

# %%
#Removing 'Row#' column from the dataset
data = data.drop('Row#',axis=1)

# %%
data.head()
# Out:
#    clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0       37.5      0.75     0.25     0.25   0.25              86.0
# 1       37.5      0.75     0.25     0.25   0.25              86.0
# 2       37.5      0.75     0.25     0.25   0.25              94.6
# 3       37.5      0.75     0.25     0.25   0.25              94.6
# 4       37.5      0.75     0.25     0.25   0.25              86.0
#
#    MinOfUpperTRange  AverageOfUpperTRange  MaxOfLowerTRange  MinOfLowerTRange  \
# 0              52.0                  71.9              62.0              30.0
# 1              52.0                  71.9              62.0              30.0
# 2              57.2                  79.0              68.2              33.0
# 3              57.2                  79.0              68.2              33.0
# 4              52.0                  71.9              62.0              30.0
#
#    AverageOfLowerTRange  RainingDays  AverageRainingDays  fruitset  fruitmass  \
# ...

# %%
X = data.loc[:,'clonesize':'seeds'] #gives list of predictors

# %%
Y = print(data.loc[:,'yield']) #dependent variable
# Out:
# 0      3813.165795
# 1      4947.605663
# 2      3866.798965
# 3      4303.943030
# 4      3436.493543
#           ...
# 772    5333.873335
# 773    3373.436842
# 774    4203.027624
# 775    4166.299735
# 776    3943.131681
# Name: yield, Length: 777, dtype: float64

# %%
y = Y.values

# %%
y = y.reshape(-1,1)
y.ndim
# Out:
# 2

# %%
#Univariate Analysis for Target column
#We have no null values and overall datatype of the dataset is float.

figs=plt.figure(figsize=(15,7))
plt.title("Blueberry Yield Curve")
ax1=figs.add_subplot(121)
ax2=figs.add_subplot(122)
x=data['yield']
plt.xlabel("Yield Value")
ax1.hist(x,bins=20,color="salmon")
ax2.boxplot(x)

#In the very first step, we are looking at how the target variable looks like and what is it's nature.
#As the column is numeric we can plot Histogram,which has a tail heavy nature,but it looks normal
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ffdaad46d00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ffdaad5a400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ffdaad46850>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffdaad5aac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffdaad5ae20>],
#  'means': []}

# %%
#Univariate Analysis for Independent features
unpivot = pd.melt(data,data.describe().columns[-1],data.describe().columns[:-1])

g=sns.FacetGrid(unpivot,col="variable",col_wrap=3,sharex=False,sharey=False)
g.map(sns.kdeplot,"value")

plt.show()

# %%
unpivot=pd.melt(data,data.describe().columns[-1],data.describe().columns[:-1])
g=sns.FacetGrid(unpivot,col="variable",col_wrap=3,sharex=False,sharey=False)
g.map(sns.boxplot,"value")

plt.show()
# Out:
# /Users/ankitagoyal/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:643: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#The value of honeybee is loosely skewed and is lying towards 0 so we can drop that column

# %%
#MultiVariate Analysis

plt.figure(figsize=(17,12))
sns.set()
sns.heatmap(data.corr(),annot=True,cmap=plt.cm.CMRmap_r)
# Out:
# <AxesSubplot:>

# %%
# pearson's correlation feature selection for numeric input and numeric output
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
# define feature selection
fs = SelectKBest(score_func=f_regression, k=10)
# apply feature selection
X_selected = fs.fit_transform(X, Y)
print(X_selected.shape)
# Out:
# (777, 10)

# %%
from sklearn import preprocessing

lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(Y)

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(Xt, encoded)
print(model.feature_importances_)
feat_importances = pd.Series(model.feature_importances_, index=Xt.columns)
feat_importances.nlargest(17).plot.bar()
plt.show()
list1=feat_importances.keys().to_list()
# Out:
# [0.02131443 0.02046392 0.02835052 0.13524485 0.11309278 0.00427835
#  0.00448454 0.00429124 0.0044201  0.0048067  0.00425258 0.03992268
#  0.0408634  0.19239691 0.18726804 0.19454897]

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
chi2_features = SelectKBest(chi2, k = 10) 
X_kbest_features = chi2_features.fit_transform(X, encoded)
mask=chi2_features.get_support()
new_feature=[]
for bool,feature in zip(mask,X.columns):
    if bool:
        new_feature.append(feature)
list3=new_feature
list3
# Out:
# ['clonesize',
#  'honeybee',
#  'MaxOfUpperTRange',
#  'MinOfUpperTRange',
#  'AverageOfUpperTRange',
#  'MaxOfLowerTRange',
#  'MinOfLowerTRange',
#  'AverageOfLowerTRange',
#  'RainingDays',
#  'seeds']

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0.2)
var_thres.fit(X)
var_thres.get_support()
# Out:
# array([ True,  True, False, False, False,  True,  True,  True,  True,
#         True,  True,  True, False, False, False,  True])

# %%
X.columns[var_thres.get_support()]
# Out:
# Index(['clonesize', 'honeybee', 'MaxOfUpperTRange', 'MinOfUpperTRange',
#        'AverageOfUpperTRange', 'MaxOfLowerTRange', 'MinOfLowerTRange',
#        'AverageOfLowerTRange', 'RainingDays', 'seeds'],
#       dtype='object')

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = X.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X, 0.85)
len(set(corr_features))
corr_features
# Out:
# {'AverageOfLowerTRange',
#  'AverageOfUpperTRange',
#  'AverageRainingDays',
#  'MaxOfLowerTRange',
#  'MinOfLowerTRange',
#  'MinOfUpperTRange',
#  'fruitmass',
#  'seeds'}

# %%
X = X.drop(['AverageOfLowerTRange',
 'AverageOfUpperTRange',
 'AverageRainingDays',
 'MaxOfLowerTRange',
 'MinOfLowerTRange',
 'MinOfUpperTRange',
 'fruitmass',
 'seeds'],axis=1)

# %%
X
# Out:
#      clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 0         37.5     0.750    0.250    0.250  0.250              86.0
# 1         37.5     0.750    0.250    0.250  0.250              86.0
# 2         37.5     0.750    0.250    0.250  0.250              94.6
# 3         37.5     0.750    0.250    0.250  0.250              94.6
# 4         37.5     0.750    0.250    0.250  0.250              86.0
# ..         ...       ...      ...      ...    ...               ...
# 772       10.0     0.537    0.117    0.409  0.058              86.0
# 773       40.0     0.537    0.117    0.409  0.058              86.0
# 774       20.0     0.537    0.117    0.409  0.058              86.0
# 775       20.0     0.537    0.117    0.409  0.058              89.0
# 776       20.0     0.537    0.117    0.409  0.058              89.0
#
#      RainingDays  fruitset
# 0          16.00  0.410652
# 1           1.00  0.444254
# 2          16.00  0.383787
# 3           1.00  0.407564
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = X.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X,Y)
mutual_info
# Out:
# array([0.17963385, 0.10674653, 0.05099775, 0.04601496, 0.09166161,
#        0.12170954, 0.21635154, 1.94885342])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X.columns
mutual_info.sort_values(ascending=False)
# Out:
# fruitset            1.948853
# RainingDays         0.216352
# clonesize           0.179634
# MaxOfUpperTRange    0.121710
# honeybee            0.106747
# osmia               0.091662
# bumbles             0.050998
# andrena             0.046015
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(X,y)
# Out:
# <ipython-input-301-a105044660f8>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selection.fit(Xt,y)
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [0.00661344 0.00321473 0.00178353 0.00232352 0.00397802 0.00376457
#  0.00367751 0.00430277 0.0039991  0.00621819 0.00470194 0.01377249
#  0.01039252 0.41443395 0.22027701 0.29654674]

# %%
plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=Xt.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((621, 8), (621,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((156, 8), (156,))

# %%
X_train.head()
# Out:
#      clonesize  honeybee  bumbles  andrena  osmia  MaxOfUpperTRange  \
# 642       25.0      0.50     0.25     0.75   0.75              77.4
# 118       12.5      0.25     0.25     0.25   0.75              94.6
# 429       12.5      0.25     0.38     0.50   0.63              69.7
# 482       25.0      0.50     0.25     0.38   0.63              77.4
# 355       12.5      0.25     0.38     0.38   0.50              86.0
#
#      RainingDays  fruitset
# 642          1.0  0.532557
# 118          1.0  0.609613
# 429         16.0  0.564795
# 482          1.0  0.536900
# 355         16.0  0.621376

# %%
# data normalization with sklearn
from sklearn.preprocessing import MinMaxScaler

# fit scaler on training data
norm = MinMaxScaler().fit(X_train)

# transform training data
X_train = norm.transform(X_train)

# transform testing dataabs
X_test = norm.transform(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
# array([[0.91666667, 0.11295181, 0.42735043, ..., 0.30923695, 0.        ,
#         0.59126441],
#        [0.5       , 0.0753012 , 0.42735043, ..., 0.        , 1.        ,
#         0.43082473],
#        [0.08333333, 0.0376506 , 0.42735043, ..., 1.        , 0.45454545,
#         0.88902599],
#        ...,
#        [0.5       , 0.0753012 , 0.42735043, ..., 1.        , 0.        ,
#         0.66654821],
#        [0.5       , 0.0753012 , 0.42735043, ..., 0.30923695, 0.45454545,
#         0.68419784],
#        [0.5       , 0.0753012 , 0.42735043, ..., 0.65461847, 0.45454545,
#         0.68264264]])

# %%
Y_pred = model.predict(X_test)

# %%
yyp = pd.DataFrame(Y_pred)

# %%
yyt = pd.DataFrame(Y_test)

# %%
prediction = model.predict(X_test)
r2 = r2_score(Y_test,Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
print('Coefficients:', model.coef_)
print(f'------------------------------')
print("The R2 score of the model is: ", r2)
print("The MSE score of the model is: ", mse)
# Out:
# Coefficients: [[-142.31499702 -568.92127856  587.97049908  146.9676378   449.32266171
#   -238.76835939 -505.61341099 6721.94919182]]
# ------------------------------
# The R2 score of the model is:  0.9681841055600683
# The MSE score of the model is:  52206.77699563544

# %%
plt.scatter(Y_test, Y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train, Y_train)
# Out:
# <ipython-input-308-c332f1a5ad6e>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   reg_rf.fit(X_train, Y_train)
# RandomForestRegressor()

# %%
y_pred = reg_rf.predict(X_test)

# %%
reg_rf.score(X_train, Y_train)
# Out:
# 0.9980673453673115

# %%
reg_rf.score(X_test, Y_test)
# Out:
# 0.9854191246739029

# %%
sns.distplot(Y_test - y_pred)
plt.show()
# Out:
# C:\Users\djkde\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(Y_test, y_pred, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
from sklearn import metrics

print("MAE:", metrics.mean_absolute_error(Y_test, y_pred))
print("MSE:", metrics.mean_squared_error(Y_test, y_pred))
print("RMSE:", np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
print("R^2 Score: ",metrics.r2_score(Y_test, y_pred))
# Out:
# MAE: 126.38466643269213
# MSE: 28052.85021437074
# RMSE: 167.48985107871684
# R^2 Score:  0.9854191246739029

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = reg_rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\djkde\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:531: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   0.9s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 5,
#  'min_samples_leaf': 5,
#  'max_features': 'auto',
#  'max_depth': 15}

# %%
prediction = rf_random.predict(X_test)

# %%
plt.figure(figsize = (8,8))
sns.distplot(Y_test-prediction)
plt.show()
# Out:
# C:\Users\djkde\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(8,8))
plt.scatter(Y_test, prediction, alpha = 0.5)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
print("MAE:", metrics.mean_absolute_error(Y_test, prediction))
print("MSE:", metrics.mean_squared_error(Y_test, prediction))
print("RMSE:", np.sqrt(metrics.mean_squared_error(Y_test, prediction)))
print("R^2 Score: ",metrics.r2_score(Y_test, y_pred))
# Out:
# MAE: 132.33689136988227
# MSE: 31394.41914078702
# RMSE: 177.18470346163357
# R^2 Score:  0.9854191246739029

# %%
import pickle

# Open a file, where you want to store the data
file = open('wildberry_rf_model.pkl', 'wb')

# pickle.dump(reg_rf, file)

pickle.dump(rf_random, file)
